# %%
import sys
print(sys.version)
import itertools

import numpy as np
import scipy as sp
import qutip as qp
import matplotlib.pyplot as plt
# Out:
# 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:24:51) [MSC v.1940 64 bit (AMD64)]

# %% [markdown]
# # Transmon diagonalization

# %%
class TmonParams:
    def __init__(
            self, EC=0.2, EJ=22, alpha=0.25, flux_ext=0, c1=1, c2=0,
            basis: str="charge", eigensystem_n: int=3, charge_n_max: int=5
        ):
        r"""
        Parameters
        ----------
        EC: float
            Ec = \frac{e^2}/{2 h C} [GHz]
            Ec entries hamiltonian as `4 Ec n^2`
        EJ: float
            EJ = \frac{Ic}{2e} \frac{1}{2pi} [GHz] 
        alpha: float
            E_{J1}/E_{J2} in [0, 1]
        flux_ext: float
            external flux normalized in [0, 1]
        c1: float
            external flux coefficient at branch E_{J1}
        c2: float
            external flux coefficient at branch E_{J2}
         tmon_params: TmonParams
            Transmon model physical parameters
        basis: str
            Type of basis to solve in "charge" or "flux"
        eigensystem_n: int
            number of eigenfunctions to find
        charge_n_max: int
            size of charge basis
        """
        self.EC: float = EC
        self.EJ: float = EJ
        self.alpha: float = alpha
        self.flux_ext: float = flux_ext
        self.c1: float = c1
        self.c2: float = c2

        # eigenvectrors basis (charge or flux)
        self.basis: str = basis
        self.eigensystem_n: int = eigensystem_n  # amount of vectors in eigenbasis to find
        self.charge_n_max: int = charge_n_max  # charge basis size

    def get_pars_tuple(self) -> tuple[float]:
        return (self.EC, self.EJ, self.alpha, self.flux_ext, self.c1, self.c2)

class Tmon:
    def __init__(self, tmon_params: TmonParams=TmonParams()):
        self.pars: TmonParams = tmon_params

    @staticmethod    
    def construct_ec_cb(tmon_pars) -> np.ndarray:
        r"""
        H 4*E_C*n^2
        H = 4*E_C*\hat{n}^2
        """
        pars = tmon_pars
        diag_entries = [i**2 for i in range(-pars.charge_n_max, pars.charge_n_max + 1)]
        ec = 4*pars.EC*qp.qdiags(diagonals=[diag_entries], offsets=[0])
        return ec

    @staticmethod
    def construct_ej_cb(tmon_pars) -> np.ndarray:
        r"""
        - alpha * E_J * cos(phi - c1*flux_ext) - E_J * cos(phi - c2*flux_ext)
         - \alpha* E_J * \cos({\hat{\phi} - c1*\phi_{ext}}) - E_J * \cos({\hat{\phi} - c2*\phi_{ext}})
        """
        def get_ejj_cb(ej, phi_ext):
            # return ej*cos(\op(phi) - phi_ext) in charge basis
            ejj = qp.qdiags(
                diagonals=[
                    (ej*np.exp(-1j*2*np.pi*phi_ext))*np.ones(2*tmon_pars.charge_n_max),  # upper diagonal
                    (ej*np.exp(1j*2*np.pi*phi_ext))*np.ones(2*tmon_pars.charge_n_max)  # lower diagonal
                ],
                offsets=[1, -1]
            )
            return 1/2*ejj
        pars = tmon_pars
        Ejj1 = get_ejj_cb(ej=pars.alpha*pars.EJ, phi_ext=pars.c1*pars.flux_ext)
        Ejj2 = get_ejj_cb(ej=pars.EJ, phi_ext=pars.c2*pars.flux_ext)
        return -Ejj1 - Ejj2
    
    @staticmethod
    def get_h_cb(tmon_pars: TmonParams) -> qp.Qobj:
        r"""
        H = 4*E_C*n^2 - alpha * E_J * cos(phi - c1*flux_ext) - E_J * cos(phi - c2*flux_ext)
        H = 4*E_C*\hat{n}^2 - \alpha* E_J * \cos({\hat{\phi} - c1*\phi_{ext}}) - E_J * \cos({\hat{\phi} - c2*\phi_{ext}})
        """
        Hc = Tmon.construct_ec_cb(tmon_pars=tmon_pars)
        Hj = Tmon.construct_ej_cb(tmon_pars=tmon_pars)
        return Hc + Hj

# %%
phi_ext_n : int = 20
phi_ext_arr = np.linspace(start=0, stop=1, num=phi_ext_n, endpoint=False)

eigvals_n = 3
evals_arr = []
evecs_arr = []


for phi_idx, phi_ext in enumerate(phi_ext_arr):
    h = Tmon.get_h_cb(TmonParams(flux_ext=phi_ext))
    evals, evecs = h.eigenstates(eigvals=eigvals_n)
    evals_arr.append(evals[1:2] - evals[0])
    evecs_arr.append(evecs)

evals_arr = np.array(evals_arr)
evecs_arr = np.array(evecs_arr)

# %%
fig, ax = plt.subplots(1,1)
for evals in evals_arr.T:
    ax.plot(phi_ext_arr, evals)

# %% [markdown]
# # Resonator + Tmon diagonalization

# %%
class RoResParams:
    def __init__(self, freq=7.2, kappa=2e-3, gc=12e-3, max_excitations=5) -> None:
        r"""
        Physical paramters of a lamda/4 coplanar waveguide readout resonator
        freq: float
            [GHz] resonator frequency
        kappa: float
            [Ghz] photon loss rate into readout waveguide
        gc: float
            [Ghz] coupling between resonator and qubit $H_{int} = g_c \sigma_x (a + a^{dag})$
        max_excitations: int
        """
        self.freq = freq
        self.kappa = kappa
        self.gc = gc

        self.max_excitations = 5

class RoResonator:
    def __init__(self, pars: RoResParams = RoResParams()):
        self.pars = pars

    @staticmethod
    def get_h_osc(pars: RoResParams = RoResParams()):
        r"""
        Oscillator energy
        E_r/h = \nu_r a a^{\dag}
        """
        return pars.freq*qp.num(N=pars.max_excitations)

# %%
t_pars = TmonParams(eigensystem_n=4)
r_pars = RoResParams()
phi_ext_arr = np.linspace(start=0, stop=1, num=20, endpoint=False)
n_op_eigh_list = []
evals_arr = []
evecs_arr = []
# prepare many-time used operators
n_op = qp.charge(Nmax=t_pars.charge_n_max)
pos = np.sqrt(2) * qp.position(N=r_pars.max_excitations)
h_osc = qp.tensor(qp.identity(t_pars.eigensystem_n), RoResonator.get_h_osc(r_pars))

for phi in phi_ext_arr:
    t_pars.flux_ext = phi
    h_tmon_cb = Tmon.get_h_cb(tmon_pars=t_pars)

    evals, evecs_Sm = h_tmon_cb.eigenstates(eigvals=t_pars.eigensystem_n)
    # charge operator in eigenbasis
    n_op_eigh = np.empty((len(evals), len(evals)), dtype=complex)
    for (i, v1), (j, v2) in itertools.product(enumerate(evecs_Sm), enumerate(evecs_Sm)):
        n_op_eigh[i,j] = v1.full().T.dot(n_op.full()).dot(v2.full())[0,0]
    n_op_eigh = qp.Qobj(n_op_eigh)
    
    h_q = qp.tensor(qp.qdiags(evals-evals[0]), qp.identity(r_pars.max_excitations)) 
    h_int = r_pars.gc*np.sqrt(2)*qp.tensor(n_op_eigh, pos)
    h = h_q + h_osc + h_int
    evals, evecs = h.eigenstates(eigvals=4)
    evals_arr.append(evals)
    evecs_arr.append(evecs)

evals_arr = np.array(evals_arr).T

# %%
fig, ax = plt.subplots(1,1)
for evals in (evals_arr - evals_arr[0]):
    ax.plot(phi_ext_arr, evals)
# Out:
# c:\Users\botan\anaconda3\envs\qp-nbs\Lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\botan\anaconda3\envs\qp-nbs\Lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # decay rates simulation
# Verification of decay rates from readout resonator

# %% [markdown]
# ## Theory

# %% [markdown]
# If interaction between bath consisting of single bosonic mode can be written as:
# $$H_I/\hbar \propto g\left( b e^{-i\omega_E t} + b^{\dag} e^{i \omega_E t} \right) \left( A_-e^{-i\omega_s t} + A_+ e^{i \omega_s t} \right)$$
# bath is described by boson modes $b$ and has:<br>
# a) no squeezed modes <br>
# b) correlated frequencies<br>
# <br>
# and if Linblad operator is written as
# $$L[a](\rho) = a \rho a^{\dag} - 1/2 \left(a^{\dag} a, \rho + \rho a^{\dag} a\right) = b \rho a^{\dag} - 1/2 \left\{{a^{\dag} a, \rho } \right\}$$
# then
# $$ \partial_t \rho = ... +\; (n+1) \gamma L[a](\rho) + n \gamma L[a^{\dag}](\rho) $$
# $$ \gamma = \sqrt{\frac{g}{2 \pi}} $$
# and collacpse operators (quantum jumps approach) are
# $$C_1 = \sqrt{\gamma (n+1)} A_-(t) \quad C_2 = \sqrt{\gamma n} A_+(t)$$
# where $n = \langle b^{\dag} b \rangle$ for external bath.

# %% [markdown]
# Above equations may differ from a lot of authtors up to $\gamma \rightarrow \gamma/2$ depending on the Linblad operator definition (definition here):
# $$L \coloneqq a \rho a^{\dag} - ...$$
# or (from Collet and Gardiner 1984, as well as Zagoskin):
# $$L \coloneqq 2 a \rho a^{\dag} - ... $$

# %% [markdown]
# Further we assume that bath temperature is zero.<br>
# Moving to interaction picture with $H_0 = \omega_c a a^{\dag}$:
# $$ H \rightarrow 0 $$
# $$ a \rightarrow a e^{-i \omega_r t} = a_I $$

# %% [markdown]
# We have
# $$ \partial_t \rho_I = \gamma L[a_I](\rho_I) =  \gamma L[a](\rho_I)$$
# In last equality we used that $\hat{a}_I = \hat{a} e^{-i\omega_c t}$ and interaction picture rotation cancels out.<br>
#  $\langle a \rangle(t) \propto e^{-\gamma t/2}$

# %%
gamma = 0.1
n_basis = 10
alpha = 2
psi_0 = qp.coherent(N=n_basis, alpha=alpha)
a = qp.destroy(N=n_basis)

times = np.linspace(0,20, 100)

# monte-carlo solution


# linblad solution
sol_res = qp.mesolve(H=qp.qzero(n_basis), rho0=psi_0, tlist=times, c_ops=[np.sqrt(gamma)*a], e_ops=[qp.num(n_basis)])
y = sol_res.expect[0]
# fit with decay exponent
def f(t, *p):
    y = p[0]*np.exp(- p[1]*t) + p[2]
    return y
fit_res = sp.optimize.curve_fit(f, times, y, p0=[alpha, 5*gamma, 0])

fig, ax = plt.subplots(1,1)
ax.scatter(times, y)
ax.plot(
    times, f(times, *fit_res[0]), 'r-',
      label=r"$\langle a^{\dag}a \rangle (t) = A e^{-\kappa t} + C$" + "\n" + 
      fr"$\kappa = {fit_res[0][1]:.4} = \gamma$" + "\n" +
      r"$ c_{op} = \sqrt{\gamma/2} \hat{a}$"
)
ax.legend()

# %% [markdown]
# # Modeling 1way-waveguide + readout resonator + qubit
# $$ H/\hbar = H_q + g_c \hat{n} (\hat{a} + \hat{a}^{\dagger}) + \omega_r \hat{a}^{\dag} \hat{a} + \int_0^{\infty} d\omega \;\kappa_(\omega)(\hat{a} + \hat{a}^{\dag} )(\hat{b}_{\omega} + \hat{b}_{\omega}^{\dag}) + \int_{0}^{\infty} d\omega \; \omega \hat{b}_{\omega}^{\dag}\hat{b}_{\omega} $$

# %% [markdown]
# ## qubit+resonator dumped dynamics (Lindblad)
# using derivation from Zegoskin (1.3.2)
# $$ H/\hbar = H_q + g_c (n_+ a e^{-i \omega_r t} + n_- a^{\dag}e^{i \omega_r t}) $$

# %% [markdown]
# what's next?
#
# 1. $\kappa(\omega) = \sqrt{\gamma/2\pi}$
# 2. qubit/resonator dynamics for initial states and no incident wave in waveguide (get modified decay coefficient and compare with analytic results)
# 3. $S_{21}(\omega_w)$, where $\omega_w$ - carrying frequency of a waveguide scan frequency. From external flux (basically STS).
# 4. same but with qubit periodic pumping through control line (add control line decay?, skip for starters)
# 5. $S_{21}(\omega_s)$, where $\omega_s$ - carrying frequency of a qubit pumping. From external flux (basicall TTS)
# 6. Add realistic control line decay and verify that results does not change much.

# %% [markdown]
# ## Flux operator in cooper pairs excess number basis (charge basis).
# $$\cos({\alpha \hat{\phi} - \phi_{ext}}) = \frac{1}{2} \left( e^{-i\phi_{ext}} \left( \sum_{m} \ket{m+\alpha}\bra{m} \right) +  e^{i \phi_{ext}} \left( \sum_{m}\ket{m}\bra{m-\alpha} \right) \right)$$
#
# ## Comment
# If $\alpha != 1$, than rescaling of the corresponding variable has to take, such that new variable has $\alpha = 1$ and hence lives in $(-\pi, \pi)$ domain?? And then its corresponding momentum lives has step that equals 2? or 1?
# Connect this with commutation relation between charge and branch/node flux. Relation that is yet unknown to me.
# Josephson relations can lead to the answer:
# $$ \hbar \dot{\phi} = 2e V $$
# $$ \phi / 2 \pi = 2e/h \Phi $$
# lhs has values in $[0;1]$ (no need wider, since motion equations are invariant under translation over $\phi$ by $2\pi$), hence
# $$ \Phi \in [0; h/2e] $$
#
# After that we should use the following relation between quantum momentum and its corresponding coordinate operators:
# $$[\hat q,\hat p] = i\hbar \{q,p\}$$
# Where $\{\cdot, \cdot\}$ - Poisson brackets:
# $$ \{f,g\} ~:=~ \sum_{i=1}^{N} \left[
# \frac{\partial f}{\partial q_{i}} \frac{\partial g}{\partial p_{i}} -
# \frac{\partial f}{\partial p_{i}} \frac{\partial g}{\partial q_{i}}
# \right] $$
# In 1D-case, we set $f = q, g = p$ and obtain
# $$ [\hat{q}, \hat{p}] = i \hbar (1 - 0) = i \hbar $$
#
# We got to add here, that eigenvalues of coordinate and momentum are related as summation indices of a corresponding Fourier representation (in momentum basis or coordinate basis).
#
# TODO: proof that eigenv
# alues of $P_{\phi} 1/\hbar$ coinside with integers if eigenvalues of $\phi$ coiside with $ [0, 2\pi)$

# %% [markdown]
# ### Proof of the main statement
# We have $\cos(\alpha \hat{\phi} - \phi_{ext})$ in josephson junction's hamiltonian and wish compute hamiltonian in charge basis.

# %% [markdown]
# $\cos({\alpha \hat{\phi} - \phi_{ext}}) = \frac{1}{2} (e^{i (\alpha \hat{\phi} - \phi_{ext})} + e^{ -i (\alpha \hat{\phi} - \phi_{ext})}) = \frac{1}{2} (e^{-i\phi_{ext}}e^{i \alpha \hat{\phi}} + e^{i\phi_{ext}}e^{-i \alpha \hat{\phi}})$.

# %% [markdown]
# All the data on canonical pulse and coordinate relations will be based on relation
# $$ [\hat{\phi}, \hat{n}] = i \hat{1} $$

# %% [markdown]
# We will need the following equality
#
# $$ [e^{i \alpha \hat{\phi}}, \hat{n}] = \sum_{k=0}^{\infty} \frac{i^k}{k!}\alpha^k[\phi^k, n] = - \alpha e^{i \alpha \hat{\phi}} $$

# %% [markdown]
# Proof:
# $$ [\phi^k, n] = \sum_{j=0}^{k-1} \phi^j [\phi, n] \phi^{k-1-j} = i k \phi^{k-1} $$
# $$ [e^{i \alpha \phi}, n] = \sum_{k=1}^{\infty} \frac{i^k}{k!} \alpha^k (i k \phi^{k-1})  = \alpha (i^2)\sum_{k=1}^{\infty} \frac{i^{k-1}}{(k-1)!} \alpha^{k-1} \phi^{k-1} = - \alpha e^{i \alpha \phi} $$
# As a result we may substitute $\phi \rightarrow \alpha \phi$ for exponents as well.

# %% [markdown]
# Now we can apply both parts to the vector $\ket{m}$, such that $\hat{n}\ket{m} = m\ket{m}$
# $$ e^{i\alpha \hat{\phi}} \hat{n} \ket{m} - \hat{n} e^{i \alpha \hat{\phi}} \ket{m} = - \alpha e^{\alpha\hat{\phi}} \ket{m} $$
# $$ \hat{n} e^{i \alpha\hat{\phi}} \ket{m} = (m + \alpha) e^{i \alpha\hat{\phi}} \ket{m}$$
#
# Hence $e^{i \alpha\hat{\phi}} \ket{m}$ is the eigenvector of the operator $\hat{n}$ with the eigenvalue $m+\alpha$:
# $$ e^{i \alpha\hat{\phi}} \ket{m} = c_m \ket{m+\alpha} $$
#
# If $\hat{\phi}$ is hermitian then $e^{i\hat{\phi}}$ is unitary. Adding that $\ket{n}$ are normalized $c_m = e^{i \beta_m}, \; \beta_m \in [0,2\pi)$
# $$ e^{i \alpha \hat{\phi}} \ket{m} = e^{i \beta_m} \ket{m+\alpha} $$

# %% [markdown]
# Using that (todo: derive from $[\phi, n] = i$ and formal series/generalized functions)
# $$ \bra{\phi} \hat{n} \ket{\psi} = -i \frac{\partial}{\partial \phi} \psi(\phi) $$
# or if written properly in braket notation with use of a generalized Loran-Schwartz functions:
# $$ \sum_{\phi'} \bra{\phi}\hat{n} \ket{\phi} \braket{\phi' \vert \psi} = i \langle \delta'_{\phi'}(\phi' - \phi), \psi(\phi')\rangle_{\phi'} $$
#
# One can establish a connection between canonical momentum and coordinate basises.
# Writing equation for momentum eigenfunctions in coordinate basis:
# $$ -i\partial_{\phi} \psi_m = m \psi_m $$
# $$ \psi_m(\phi) = C_m e^{i m \phi} $$
# No matter what variable types are momentum and coordinate (discrete, continious, periodic) $\phi$ normalization gives $\lvert C_m \rvert = 1/\sqrt{2 \pi}$
# We choose
# $$ \psi_m(\phi) = \frac{1}{\sqrt{2 \pi}} e^{m \phi} $$

# %% [markdown]
# In bracket notation
# $$ \braket{\phi \vert m} = \frac{1}{\sqrt{2 \pi}} e^{i m \phi} $$
# $$ \braket{m \vert\phi} = \frac{1}{\sqrt{2 \pi}} e^{-i m \phi}$$
#
# $\ket{\phi}$ can be represented in a charge basis:
# $$ \ket{\phi} = \sum_{m} \frac{1}{\sqrt{2 \pi}} e^{-i m \phi} \ket{m} $$
#
# Using that $\hat{\phi}$ and $e^{i \alpha \hat{\phi}}$ has the same eigensystems
# $$e^{i \alpha \hat{\phi}}\ket{\phi} = e^{i \alpha \phi}\ket{\phi} = (1) $$
#
# On the other hand :
# $$e^{i \alpha \hat{\phi}} \ket{\phi} = \sum_{m} \braket{m \vert \phi} e^{i \alpha \hat{\phi}} \ket{m} = \sum_{m} \braket{m \vert \phi} c_m \ket{m+\alpha} = (2) $$
#
# Equalizing $(1)$ and $(2)$  (both results for $e^{i \alpha \hat{\phi}}\ket{\phi}$) and projecting them on the momentum eigenfunction $\ket{k}$
# $$ e^{i \alpha \phi} \braket{k \vert \phi} = \braket{k-\alpha \vert \phi} c_{k} $$
# $$ c_m = e^{i \alpha \phi} \frac{\braket{m \vert \phi}}{\braket{m - \alpha \vert \phi}} = 1$$
#
# We have derived
# $$ e^{i \alpha \hat{\phi}} = \sum_{m}\ket{m+\alpha}\bra{m}$$

# %% [markdown]
# $$\cos({\alpha \hat{\phi} - \phi_{ext}}) = \frac{1}{2} \left( e^{-i\phi_{ext}} \left( \sum_{m} \ket{m+\alpha}\bra{m} \right) +  e^{i \phi_{ext}} \left( \sum_{m}\ket{m-\alpha}\bra{m} \right) \right)$$

# %% [markdown]
# ## Interaction picture for resonator operators
# $$ \hat{H}_0/\hbar = \omega_r \hat{a}^{\dag} \hat{a} $$
# $$ \hat{a_I} = \hat{a} e^{- i \omega_r t} $$

# %% [markdown]
# ### Proof

# %% [markdown]
# $$ a_I = U_0^{\dag} a U_0 \quad U_0 = \exp(-i H_0/\hbar t) $$
# $$ \frac{d a_I}{d t} =  i\omega_r [\hat{n}, a_I] = \big\vert [\hat{n}, U_0] = 0 \big\vert = - i \omega_r a_I $$

# %% [markdown]
# ## Qubit-resonator coupling

# %% [markdown]
# ![image.png](attachment:84e13089-fc27-4e1a-ad5e-7791674a8f2d.png)
# ![image.png](attachment:c832b454-5c6c-444d-8c8f-6d05339b4666.png)

# %% [markdown]
# ![image.png](attachment:1e5840a8-0739-48e0-99e7-379079cdf915.png)

# %% [markdown]
# ![image.png](attachment:cce88ca8-a561-4b8f-81cc-e1f160c2d302.png)

# %% [markdown]
# ![image.png](attachment:f2ff89b3-dc07-4031-8234-94dbc86cf650.png)

# %% [markdown]
# ![image.png](attachment:c4d3f524-303e-42a7-a75c-cb5eb5de1bb8.png)

# %% [markdown]
# ![image.png](attachment:c51eb3f7-6a73-4bc3-ab45-11c63a49249b.png)

# %% [markdown]
# ![image.png](attachment:6ac8de6e-9c02-45f3-acd7-a50b89ec869b.png)

# %% [markdown]
# ![image.png](attachment:1195042e-88c8-4f5d-935f-f2eaef42ba38.png)

# %% [markdown]
# ![image.png](attachment:10b70c08-1d04-4383-b9f8-004dd583b0e5.png)
